# %%
import pandas as pd

# %%
path: str = "../../data/processed/all_games_merged_new_processed.jsonl"
df: pd.DataFrame = pd.read_json(path, lines=True)

# %%
df.head()
# Out:
#                 game benchmark_version  game_id  \
# 0  wordle_withcritic              v1.5        1
# 1  wordle_withcritic              v1.5        2
# 2  wordle_withcritic              v1.5        3
# 3  wordle_withcritic              v1.5        4
# 4  wordle_withcritic              v1.5        5
#
#                                                model  \
# 0  CodeLlama-34b-Instruct-hf-t0.0--CodeLlama-34b-...
# 1  CodeLlama-34b-Instruct-hf-t0.0--CodeLlama-34b-...
# 2  CodeLlama-34b-Instruct-hf-t0.0--CodeLlama-34b-...
# 3  CodeLlama-34b-Instruct-hf-t0.0--CodeLlama-34b-...
# 4  CodeLlama-34b-Instruct-hf-t0.0--CodeLlama-34b-...
#
#                                 experiment    episode  Aborted  Lose  Success  \
# 0  0_high_frequency_words_clue_with_critic  episode_0        1     0        0
# 1  0_high_frequency_words_clue_with_critic  episode_1        1     0        0
# 2  0_high_frequency_words_clue_with_critic  episode_2        1     0        0
# 3  0_high_frequency_words_clue_with_critic  episode_3        1     0        0
# 4  0_high_frequency_words_clue_with_critic  episode_4        1     0        0
#
#                                                 chat target    player
# 0  [{'role': 'user', 'content': 'You are a langua...  start  player 1
# 1  [{'role': 'user', 'content': 'You are a langua...  share  player 1
# 2  [{'role': 'user', 'content': 'You are a langua...  third  player 1
# 3  [{'role': 'user', 'content': 'You are a langua...  photo  player 1
# 4  [{'role': 'user', 'content': 'You are a langua...  might  player 1

# %%
df[df.target == 'trial']
# Out:
#                     game benchmark_version  game_id  \
# 28     wordle_withcritic              v1.5        9
# 58     wordle_withcritic              v1.5        9
# 88     wordle_withcritic              v1.5        9
# 118    wordle_withcritic              v1.5        9
# 146    wordle_withcritic              v1.5        9
# ...                  ...               ...      ...
# 92107             wordle    v1.6_quantized        9
# 92137             wordle    v1.6_quantized        9
# 92167             wordle    v1.6_quantized        9
# 92197             wordle    v1.6_quantized        9
# 92227             wordle    v1.6_quantized        9
#
#                                                    model  \
# 28     CodeLlama-34b-Instruct-hf-t0.0--CodeLlama-34b-...
# 58     Llama-3-70b-Instruct-t0.0--Llama-3-70b-Instruc...
# 88     Llama-3-8b-Instruct-t0.0--Llama-3-8b-Instruct-...
# 118    Mistral-7B-Instruct-v0.1-t0.0--Mistral-7B-Inst...
# 146    Mixtral-8x22B-Instruct-v0.1-t0.0--Mixtral-8x22...
# ...                                                  ...
# 92107  Meta-Llama-3-70B-Instruct-GGUF-q8-t0.0--Meta-L...
# 92137  Meta-Llama-3-8B-Instruct-GGUF-q4-t0.0--Meta-Ll...
# 92167  Meta-Llama-3-8B-Instruct-GGUF-q8-t0.0--Meta-Ll...
# 92197  c4ai-command-r-plus-GGUF-q4-t0.0--c4ai-command...
# 92227  c4ai-command-r-plus-GGUF-q8-t0.0--c4ai-command...
#
#                                        experiment    episode  Aborted  Lose  \
# 28      1_medium_frequency_words_clue_with_critic  episode_8        1     0
# 58      1_medium_frequency_words_clue_with_critic  episode_8        0     0
# 88      1_medium_frequency_words_clue_with_critic  episode_8        0     1
# 118     1_medium_frequency_words_clue_with_critic  episode_8        0     0
# 146     1_medium_frequency_words_clue_with_critic  episode_8        1     0
# ...                                           ...        ...      ...   ...
# 92107  1_medium_frequency_words_no_clue_no_critic  episode_8        0     1
# 92137  1_medium_frequency_words_no_clue_no_critic  episode_8        0     1
# 92167  1_medium_frequency_words_no_clue_no_critic  episode_8        0     1
# 92197  1_medium_frequency_words_no_clue_no_critic  episode_8        1     0
# 92227  1_medium_frequency_words_no_clue_no_critic  episode_8        0     1
#
#        Success                                               chat target  \
# 28           0  [{'role': 'user', 'content': 'You are a langua...  trial
# 58           1  [{'role': 'user', 'content': 'You are a langua...  trial
# 88           0  [{'role': 'user', 'content': 'You are a langua...  trial
# 118          1  [{'role': 'user', 'content': 'You are a langua...  trial
# 146          0  [{'role': 'user', 'content': 'You are a langua...  trial
# ...        ...                                                ...    ...
# 92107        0  [{'role': 'user', 'content': 'You are a langua...  trial
# 92137        0  [{'role': 'user', 'content': 'You are a langua...  trial
# 92167        0  [{'role': 'user', 'content': 'You are a langua...  trial
# 92197        0  [{'role': 'user', 'content': 'You are a langua...  trial
# 92227        0  [{'role': 'user', 'content': 'You are a langua...  trial
#
#          player
# 28     player 1
# 58     player 1
# 88     player 1
# 118    player 1
# 146    player 1
# ...         ...
# 92107  Player 1
# 92137  Player 1
# 92167  Player 1
# 92197  Player 1
# 92227  Player 1
#
# [500 rows x 12 columns]
